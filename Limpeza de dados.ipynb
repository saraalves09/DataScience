# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/DataScience/cursos-prouni.csv - cursos-prouni.csv.csv')

df.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
df.describe(include="all")
# Out:
#                grau              turno   mensalidade  bolsa_integral_cotas  \
# count         41447              41447  41447.000000          32520.000000
# unique            3                  5           NaN                   NaN
# top     Bacharelado  Curso a Distância           NaN                   NaN
# freq          19165              22926           NaN                   NaN
# mean            NaN                NaN    622.636966              1.535394
# std             NaN                NaN    606.442296              2.191578
# min             NaN                NaN    139.000000              0.000000
# 25%             NaN                NaN    278.000000              0.000000
# 50%             NaN                NaN    393.350000              1.000000
# 75%             NaN                NaN    825.000000              2.000000
# max             NaN                NaN   9999.990000             58.000000
#
# ...

# %%
print("O total de cursos foi de " + str(df.shape[0]))
# Out:
# O total de cursos foi de 41447

# %%
#removendo colunas de cidade e campus

list_drop_columns = ['cidade_filtro',
                     'campus_nome',
                     'campus_external_id']

df_aux = df.drop(columns=list_drop_columns)
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grau                  41447 non-null  object
#  1   turno                 41447 non-null  object
#  2   mensalidade           41447 non-null  float64
#  3   bolsa_integral_cotas  32520 non-null  float64
#  4   bolsa_integral_ampla  25404 non-null  float64
#  5   bolsa_parcial_cotas   8828 non-null   float64
#  6   bolsa_parcial_ampla   13041 non-null  float64
#  7   curso_id              41447 non-null  int64
#  8   curso_busca           41447 non-null  object
#  9   cidade_busca          41447 non-null  object
#  10  uf_busca              41447 non-null  object
#  11  universidade_nome     41447 non-null  object
#  12  nome                  41447 non-null  object
#  13  nota_integral_ampla   32520 non-null  float64
# ...

# %%
df_aux.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca  \
# 0     706710394154    Medicina  Campo Grande       MS
# 1  104191210567043  Enfermagem       Crateus       CE
# ...

# %%
#identificando valores nulos suspeitos

df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grau                  41447 non-null  object
#  1   turno                 41447 non-null  object
#  2   mensalidade           41447 non-null  float64
#  3   bolsa_integral_cotas  32520 non-null  float64
#  4   bolsa_integral_ampla  25404 non-null  float64
#  5   bolsa_parcial_cotas   8828 non-null   float64
#  6   bolsa_parcial_ampla   13041 non-null  float64
#  7   curso_id              41447 non-null  int64
#  8   curso_busca           41447 non-null  object
#  9   cidade_busca          41447 non-null  object
#  10  uf_busca              41447 non-null  object
#  11  universidade_nome     41447 non-null  object
#  12  nome                  41447 non-null  object
#  13  nota_integral_ampla   32520 non-null  float64
# ...

# %%
df_aux[df_aux.isna().any(axis=1)]
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral      9999.99                  15.0
# 1       Bacharelado            Noturno      9836.40                   1.0
# 3       Bacharelado            Noturno      9689.34                   3.0
# 5       Bacharelado           Integral      9650.00                   8.0
# 6       Bacharelado           Integral      9564.00                   3.0
# ...             ...                ...          ...                   ...
# 41441   Tecnológico  Curso a Distância       149.00                   0.0
# 41442  Licenciatura  Curso a Distância       149.00                   1.0
# 41444   Tecnológico         Vespertino       139.00                   1.0
# 41445   Bacharelado  Curso a Distância       139.00                   1.0
# 41446   Tecnológico  Curso a Distância       139.00                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
#removendo linhas com notas NaN
df_aux.dropna(subset=['nota_integral_ampla', 'nota_integral_cotas', 'nota_parcial_ampla', 'nota_parcial_cotas'], inplace=True)
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2203 entries, 2 to 41443
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grau                  2203 non-null   object
#  1   turno                 2203 non-null   object
#  2   mensalidade           2203 non-null   float64
#  3   bolsa_integral_cotas  2203 non-null   float64
#  4   bolsa_integral_ampla  2203 non-null   float64
#  5   bolsa_parcial_cotas   2203 non-null   float64
#  6   bolsa_parcial_ampla   2203 non-null   float64
#  7   curso_id              2203 non-null   int64
#  8   curso_busca           2203 non-null   object
#  9   cidade_busca          2203 non-null   object
#  10  uf_busca              2203 non-null   object
#  11  universidade_nome     2203 non-null   object
#  12  nome                  2203 non-null   object
#  13  nota_integral_ampla   2203 non-null   float64
# ...

# %%
df_aux.head()
# Out:
#            grau     turno  mensalidade  bolsa_integral_cotas  \
# 2   Bacharelado  Integral      9715.61                   2.0
# 4   Bacharelado  Integral      9674.34                   4.0
# 10  Bacharelado  Integral      9023.07                   4.0
# 13  Bacharelado  Integral      8508.54                   2.0
# 20  Bacharelado  Integral      8281.38                   3.0
#
#     bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 2                    5.0                  6.0                 10.0
# 4                    1.0                  5.0                  2.0
# 10                   4.0                  5.0                  5.0
# 13                   1.0                  7.0                  2.0
# 20                   1.0                  6.0                  2.0
#
#            curso_id curso_busca cidade_busca uf_busca  \
# 2     1002328574024    Medicina    Sao Paulo       SP
# 4    65899611932754    Medicina   Rio Branco       AC
# ...

# %%
#mensalidade mais barata registrada

print("Mensalidade mais barata registrada: " + str(df_aux['mensalidade'].min()))
# Out:
# Mensalidade mais barata registrada: 144.0

# %%
#mensalidade mais cara registrada

print("Mensalidade mais cara registrada: " + str(df_aux['mensalidade'].max()))
# Out:
# Mensalidade mais cara registrada: 9715.61

# %%
#menor nota integral (ampla)

print("Menor Nota Integral (Ampla): " + str(df_aux['nota_integral_ampla'].min()))
# Out:
# Menor Nota Integral (Ampla): 450.0

# %%
#maior nota integral (ampla)

print("Maior Nota Integral (Ampla): " + str(df_aux['nota_integral_ampla'].max()))
# Out:
# Maior Nota Integral (Ampla): 781.2

# %%
#menor nota integral (cotas)

print("Menor Nota Integral (Cotas): " + str(df_aux['nota_integral_cotas'].min()))
# Out:
# Menor Nota Integral (Cotas): 450.0

# %%
#maior nota integral (cotas)

print("Maior Nota Integral (Cotas): " + str(df_aux['nota_integral_cotas'].max()))
# Out:
# Maior Nota Integral (Cotas): 792.24

# %%
#menor nota parcial (ampla)

print("Menor Nota Parcial (Ampla): " + str(df_aux['nota_parcial_ampla'].min()))
# Out:
# Menor Nota Parcial (Ampla): 450.0

# %%
#maior nota parcial (ampla)

print("Maior Nota Parcial (Ampla): " + str(df_aux['nota_parcial_ampla'].max()))
# Out:
# Maior Nota Parcial (Ampla): 776.36

# %%
#menor nota parcial (cotas)

print("Menor Nota Parcial (Cotas): " + str(df_aux['nota_parcial_cotas'].min()))
# Out:
# Menor Nota Parcial (Cotas): 450.0

# %%
#maior nota parcial (cotas)

print("Maior Nota Parcial (Cotas): " + str(df_aux['nota_parcial_cotas'].max()))
# Out:
# Maior Nota Parcial (Cotas): 768.34

# %%
df_aux.to_csv('/content/drive/MyDrive/DataScience/cursos-prouni.csv - cursos-prouni-tratados.csv.csv', index=False)
